# %%
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc 

import pandas as pd 
import numpy as np
from tqdm.notebook import tqdm
import pytorch_lightning as pl
from sklearn.preprocessing import MinMaxScaler

import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))

rcParams['figure.figsize'] = 12, 8
tqdm.pandas()

# %%
pl.seed_everything(42)
# Out:
# Global seed set to 42
# 42

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("../data/01_raw/fetched_market_chart.csv", parse_dates=["timestamp"])
df = df.sort_values(by="timestamp").reset_index(drop=True)
df.head()
# Out:
#    timestamp     open     high      low    close       volume     close_time  \
# 0 2017-08-17  4261.48  4485.39  4200.74  4285.08   795.150377  1503014399999
# 1 2017-08-18  4285.08  4371.52  3938.77  4108.37  1199.888264  1503100799999
# 2 2017-08-19  4108.37  4184.69  3850.00  4139.98   381.309763  1503187199999
# 3 2017-08-20  4120.98  4211.08  4032.62  4086.29   467.083022  1503273599999
# 4 2017-08-21  4069.13  4119.62  3911.79  4016.00   691.743060  1503359999999
#
#        quote_av  trades  tb_base_av   tb_quote_av        ignore
# 0  3.454770e+06    3427  616.248541  2.678216e+06   8733.911395
# 1  5.086958e+06    5233  972.868710  4.129123e+06   9384.141409
# 2  1.549484e+06    2153  274.336042  1.118002e+06   9184.085529
# 3  1.930364e+06    2321  376.795947  1.557401e+06  10125.414084
# 4  2.797232e+06    3972  557.356107  2.255663e+06  11706.769970

# %%
df.shape
# Out:
# (1621, 12)

# %% [markdown]
# ## Preprocessing

# %%
rows = []

for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    row_data = dict(
        day_of_week=row["timestamp"].dayofweek,
        day_of_month=row["timestamp"].day,
        week_of_year=row["timestamp"].week,
        month_of_year=row["timestamp"].month,
        open=row["open"],
        high=row["high"],
        low=row["low"],
        close=row["close"],
        close_change=row["close"] - row["open"],
    )
    rows.append(row_data)

features_df = pd.DataFrame(rows)
# Out:
#   0%|          | 0/1621 [00:00<?, ?it/s]

# %%
features_df.shape
# Out:
# (1621, 9)

# %%
features_df.head()
# Out:
#    day_of_week  day_of_month  week_of_year  month_of_year     open     high  \
# 0            3            17            33              8  4261.48  4485.39
# 1            4            18            33              8  4285.08  4371.52
# 2            5            19            33              8  4108.37  4184.69
# 3            6            20            33              8  4120.98  4211.08
# 4            0            21            34              8  4069.13  4119.62
#
#        low    close  close_change
# 0  4200.74  4285.08         23.60
# 1  3938.77  4108.37       -176.71
# 2  3850.00  4139.98         31.61
# 3  4032.62  4086.29        -34.69
# 4  3911.79  4016.00        -53.13

# %%
train_size = int(len(features_df) * 0.9)
train_size
# Out:
# 1458

# %%
train_df, test_df = features_df[:train_size], features_df[train_size + 1:]
train_df.shape, test_df.shape
# Out:
# ((1458, 9), (162, 9))

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = scaler.fit(train_df)

# %%
train_df = pd.DataFrame(scaler.transform(train_df), index=train_df.index, columns=train_df.columns)
train_df.head()
# Out:
#    day_of_week  day_of_month  week_of_year  month_of_year      open      high  \
# 0     0.000000      0.066667      0.230769       0.272727 -0.964447 -0.960736
# 1     0.333333      0.133333      0.230769       0.272727 -0.963665 -0.964434
# 2     0.666667      0.200000      0.230769       0.272727 -0.969518 -0.970503
# 3     1.000000      0.266667      0.230769       0.272727 -0.969100 -0.969645
# 4    -1.000000      0.333333      0.269231       0.272727 -0.970818 -0.972616
#
#         low     close  close_change
# 0 -0.953254 -0.963698     -0.033745
# 1 -0.962104 -0.969551     -0.061151
# 2 -0.965103 -0.968504     -0.032649
# 3 -0.958934 -0.970282     -0.041720
# 4 -0.963016 -0.972610     -0.044243

# %%
test_df = pd.DataFrame(scaler.transform(test_df), index=test_df.index, columns=test_df.columns)
test_df.head()
# Out:
#       day_of_week  day_of_month  week_of_year  month_of_year      open  \
# 1459     1.000000     -0.066667      0.192308       0.272727  0.453309
# 1460    -1.000000      0.000000      0.230769       0.272727  0.450173
# 1461    -0.666667      0.066667      0.230769       0.272727  0.414652
# 1462    -0.333333      0.133333      0.230769       0.272727  0.374731
# 1463     0.000000      0.200000      0.230769       0.272727  0.374844
#
#           high       low     close  close_change
# 1459  0.432204  0.441920  0.450164     -0.049928
# 1460  0.454341  0.447325  0.414642     -0.183716
# 1461  0.425310  0.403949  0.374721     -0.201888
# 1462  0.387633  0.398114  0.375030     -0.035696
# 1463  0.421185  0.388805  0.443103      0.245044

# %%
def create_sequences(input_data: pd.DataFrame, target_column, sequence_length: int):

    sequences = []
    data_size = len(input_data)

    for i in range(data_size - sequence_length):
        sequence = input_data[i:i+sequence_length]
        label_position = i + sequence_length
        label = input_data.iloc[label_position][target_column]
        sequences.append((sequence, label))
        
    return sequences

# %% [markdown]
# ## Example with dummy df

# %%
sample_data = pd.DataFrame(dict(feature_1=[1, 2, 3, 4, 5], label=[6, 7, 8, 9, 10]))
sample_data.head()
# Out:
#    feature_1  label
# 0          1      6
# 1          2      7
# 2          3      8
# 3          4      9
# 4          5     10

# %%
sample_sequences = create_sequences(sample_data, "label", 3)
print(sample_sequences)
# Out:
# [(   feature_1  label
# 0          1      6
# 1          2      7
# 2          3      8, 9), (   feature_1  label
# 1          2      7
# 2          3      8
# 3          4      9, 10)]

# %%
len(sample_sequences)
# Out:
# 2

# %%
SEQUENCE_LENGTH = 60

train_sequences = create_sequences(train_df, "close", SEQUENCE_LENGTH)
test_sequences = create_sequences(test_df, "close", SEQUENCE_LENGTH)

# %%
train_sequences[0][0].shape
# Out:
# (60, 9)

# %%
type(train_sequences)
# Out:
# list

# %%
type(train_sequences[0])
# Out:
# tuple

# %%
type(train_sequences[0][1])
# Out:
# numpy.float64

# %%
import pandas as pd
import torch

from torch.utils.data import Dataset
from typing import List, Tuple


class CryptoDataset(Dataset):
    """
    Dataset class for the LSTM model used by PyTorch Lightning.
    """
    def __init__(self, sequences: List[Tuple[pd.DataFrame]]):
        self.sequences = sequences


    def __len__(self):
        return len(self.sequences)


    def __getitem__(self, index: int):
        sequence, label = self.sequences[index]
        return dict(
            sequence=torch.tensor(sequence.to_numpy()),
            label=torch.tensor(label).float(),
        )

# %%
train_dataset = CryptoDataset(train_sequences)

# %%
type(train_dataset[0]["label"])
# Out:
# torch.Tensor

# %%
train_df.shape
# Out:
# (1458, 9)

# %%
def extract_features_from_dataset(data: pd.DataFrame) -> pd.DataFrame:
    """
    Format market chart data to a pandas dataframe.
    """
    data = data.sort_values(by="timestamp").reset_index(drop=True)
    rows = []
    for _, row in data.iterrows():
        row_data = dict(
            day_of_week=row["timestamp"].dayofweek,
            day_of_month=row["timestamp"].day,
            week_of_year=row["timestamp"].week,
            month_of_year=row["timestamp"].month,
            open=row["open"],
            high=row["high"],
            low=row["low"],
            close=row["close"],
            close_change=row["close"] - row["open"],
        )
        rows.append(row_data)
    return pd.DataFrame(rows)


def split_data(data: pd.DataFrame) -> pd.DataFrame:
    """
    Split data into training and test sets.
    """
    train_size = int(len(data) * 0.9)
    train_df, test_df = data[:train_size], data[train_size + 1:]
    return train_df, test_df


def scale_data(train_df: pd.DataFrame, test_df: pd.DataFrame) -> pd.DataFrame:
    """
    Scale data to have a mean of 0 and a standard deviation of 1.
    """
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train_df)

    scaled_train_df = pd.DataFrame(
        scaler.transform(train_df),
        index=train_df.index, 
        columns=train_df.columns,
    )
    scaled_test_df = pd.DataFrame(
        scaler.transform(test_df),
        index=test_df.index,
        columns=test_df.columns,
    )
    return scaled_train_df, scaled_test_df


def create_sequences(
    input_data: pd.DataFrame, 
    target_column: str, 
    sequence_length: int
    ) -> List[Tuple[pd.DataFrame, float]]:
    """
    Create sequences from the input data.
    """
    sequences = []
    size = len(input_data)
    for i in range(size - sequence_length):
        sequence = input_data[i: i + sequence_length]
        label_position = i + sequence_length
        label = input_data.iloc[label_position][target_column]
        sequences.append((sequence, label))
    return sequences


def split_train_and_val_sequences(
    sequences: List[Tuple[pd.DataFrame, float]],
    val_size: float,
) -> Tuple[List[Tuple[pd.DataFrame, float]]]:
    """
    Split sequences into training and validation sets.
    """
    train_sequences, val_sequences = [], []
    for sequence, label in sequences:
        if len(train_sequences) < len(sequences) * (1 - val_size):
            train_sequences.append((sequence, label))
        else:
            val_sequences.append((sequence, label))
    return train_sequences, val_sequences

# %%
extracted_features = extract_features_from_dataset(df)
splitted_train_data, splitted_test_data = split_data(extracted_features)
scaled_train_data, scaled_test_data = scale_data(splitted_train_data, splitted_test_data)
sequences_train_data = create_sequences(scaled_train_data, "close", 7)
train_sequences, val_sequences = split_train_and_val_sequences(sequences_train_data, 0.2)
test_sequences = create_sequences(scaled_test_data, "close", 7)
# Out:
# (7, 9)
# (7, 9)

# %%
import pandas as pd
import pytorch_lightning as pl
import torch
import torch.nn as nn

from pytorch_lightning import (
    Trainer, 
    callbacks,
    seed_everything
)

from torch.utils.data import Dataset, DataLoader
from typing import List, Tuple, Dict


class CryptoDataset(Dataset):
    """
    Dataset class for the LSTM model used by PyTorch Lightning.
    """
    def __init__(self, sequences: List[Tuple[pd.DataFrame, float]]):
        self.sequences = sequences


    def __len__(self):
        return len(self.sequences)


    def __getitem__(self, index: int):
        sequence, label = self.sequences[index]
        return (torch.Tensor(sequence.to_numpy()),torch.tensor(label).float())


class LSTMDataLoader(pl.LightningDataModule):
    """
    Data loader for the LSTM model.
    """
    def __init__(self,
        train_sequences: List[Tuple[pd.DataFrame, float]],
        val_sequences: List[Tuple[pd.DataFrame, float]],
        test_sequences: List[Tuple[pd.DataFrame, float]],
        train_batch_size: int,
        val_batch_size: int,
        train_workers: int = 2,
        val_workers: int = 1,
    ):
        super().__init__()
        self.train_sequences = train_sequences
        self.val_sequences = val_sequences
        self.test_sequences = test_sequences
        self.train_batch_size = train_batch_size
        self.val_batch_size = val_batch_size
        self.train_workers = train_workers
        self.val_workers = val_workers
        self.test_workers = val_workers


    def setup(self, stage: str = None):
        """
        Load the data.
        """
        self.train_dataset = CryptoDataset(self.train_sequences)
        self.val_dataset = CryptoDataset(self.val_sequences)
        self.test_dataset = CryptoDataset(self.test_sequences)

    
    def train_dataloader(self):
        return DataLoader(
            self.train_dataset, 
            batch_size=self.train_batch_size, 
            shuffle=False,
            num_workers=self.train_workers
        )


    def val_dataloader(self):
        return DataLoader(
            self.val_dataset, 
            batch_size=self.val_batch_size, 
            shuffle=False,
            num_workers=self.val_workers
        )


    def test_dataloader(self):
        return DataLoader(
            self.test_dataset, 
            batch_size=self.val_batch_size, 
            shuffle=False,
            num_workers=self.test_workers
        )


class PricePredictionModel(nn.Module):
    """
    Standard LSTM model with PyTorch Lightning.
    """
    def __init__(self,
        batch_size: int,
        dropout_rate: float,
        hidden_size: int,
        number_of_features: int,
        number_of_layers: int,
        criterion: nn.Module = nn.MSELoss(),
    ):
        super().__init__()
        self.batch_size = batch_size
        self.criterion = criterion
        self.dropout_rate = dropout_rate
        self.hidden_size = hidden_size
        self.n_features = number_of_features
        self.number_of_layers = number_of_layers
        self.criterion = criterion

        self.lstm = nn.LSTM(
            batch_first=True,
            dropout=self.dropout_rate,
            hidden_size=self.hidden_size,
            input_size=self.n_features,
            num_layers=self.number_of_layers,
        )

        self.regressor = nn.Linear(self.hidden_size, 1)


    def forward(self, x):
        """
        Forward pass through the model.

        lstm_out = (batch_size, sequence_length, hidden_size)
        """
        self.lstm.flatten_parameters()
        _, (hidden, _) = self.lstm(x)
        out = hidden[-1]
        return self.regressor(out)


class PricePredictor(pl.LightningModule):
    """
    Training model with PyTorch Lightning.
    """
    def __init__(self,
        batch_size: int,
        dropout_rate: float,
        hidden_size: int,
        learning_rate: float,
        number_of_features: int,
        number_of_layers: int,
    ):
        super().__init__()
        self.model = PricePredictionModel(
            batch_size, dropout_rate, hidden_size, number_of_features, number_of_layers,
        )
        self.learning_rate = learning_rate


    def forward(self, x, labels=None):
        output = self.model(x)
        print(output)
        if labels is not None:
            loss = self.model.criterion(output, labels.unsqueeze(dim=1))
        else: loss = 0
        return loss, output

        
    def training_step(self, batch, batch_idx):
        sequences, labels = batch
        loss, outputs = self(sequences, labels)
        self.log("train_loss", loss, on_step=True, on_epoch=True)
        # return {"loss": loss}


    def validation_step(self, batch, batch_idx):
        sequences, labels = batch
        loss, outputs = self(sequences, labels)
        self.log("val_loss", loss, on_step=True, on_epoch=True)
        # return {"loss": loss}


    def test_step(self, batch, batch_idx):
        sequences, labels = batch
        loss, outputs = self(sequences, labels)
        self.log("test_loss", loss, on_step=True, on_epoch=True)
        # return {"loss": loss}


    def configure_optimizers(self):
        return torch.optim.AdamW(self.parameters(), lr=self.learning_rate)

# %%
def training_loop(
    train_sequences: List[Tuple[pd.DataFrame, float]], 
    val_sequences: List[Tuple[pd.DataFrame, float]],
    test_sequences: List[Tuple[pd.DataFrame, float]],
    parameters: Dict):
    """
    Training loop for the LSTM model.

    Args:
        train_sequences: List of training sequences.
        val_sequences: List of validation sequences.
        test_sequences: List of test sequences.
        parameters: Dictionary of training parameters.
    """
    seed_everything(1)


    model = PricePredictor(
        batch_size=parameters["train_batch_size"],
        dropout_rate=parameters["dropout_rate"],
        hidden_size=parameters["hidden_size"],
        learning_rate=parameters["learning_rate"],
        number_of_features=parameters["number_of_features"],
        number_of_layers=parameters["number_of_layers"],
    )

    data_module = LSTMDataLoader(
        train_sequences=train_sequences, 
        val_sequences=val_sequences,
        test_sequences=test_sequences,
        train_batch_size=parameters["train_batch_size"], 
        val_batch_size=parameters["val_batch_size"],
        train_workers=parameters["train_workers"],
        val_workers=parameters["val_workers"],
    )
    data_module.setup()

    checkpoint_callback = callbacks.ModelCheckpoint(
        filename="best-checkpoint",
        dirpath="data/06_models/checkpoints",
        save_top_k=1,
        verbose=True,
        monitor="val_loss",
        mode="min",
    )

    early_stopping_callback = callbacks.EarlyStopping(
        monitor="val_loss",
        patience=2
    )

    trainer = Trainer(
        max_epochs=parameters["max_epochs"],
        logger=False,
        checkpoint_callback=checkpoint_callback,
        callbacks=[early_stopping_callback],
        gpus=1,
        log_every_n_steps=1,
        progress_bar_refresh_rate=10,
    )

    trainer.fit(model, data_module)
    trainer.test(model, data_module)

# %%
TRAINING_PARAMS = {
    "train_batch_size": 16,
    "val_batch_size": 1,
    "train_workers": 2,
    "val_workers": 1,
    "max_epochs": 100,
    "hidden_size": 128,
    "number_of_features": 9,
    "number_of_layers": 2,
    "dropout_rate": 0.2,
    "learning_rate": 0.0001,
}

# %%
training_loop(train_sequences, val_sequences, test_sequences, TRAINING_PARAMS)
# Out:
# Global seed set to 1
# /home/chainyo/miniconda3/envs/make-me-rich/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:147: LightningDeprecationWarning: Setting `Trainer(checkpoint_callback=<pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7fe6c5892dc0>)` is deprecated in v1.5 and will be removed in v1.7. Please consider using `Trainer(enable_checkpointing=<pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7fe6c5892dc0>)`.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                 | Params
# -----------------------------------------------
# 0 | model | PricePredictionModel | 203 K
# -----------------------------------------------
# 203 K     Trainable params
# 0         Non-trainable params
# 203 K     Total params
# 0.814     Total estimated model params size (MB)
# Validation sanity check:   0%|          | 0/2 [00:00<?, ?it/s]tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# Global seed set to 1
# Epoch 0:   0%|          | 0/363 [00:00<?, ?it/s] tensor([[-0.0565],
#         [-0.0505],
#         [-0.0530],
#         [-0.0511],
#         [-0.0498],
#         [-0.0512],
#         [-0.0566],
#         [-0.0527],
#         [-0.0529],
#         [-0.0506],
#         [-0.0526],
#         [-0.0521],
#         [-0.0524],
#         [-0.0577],
#         [-0.0522],
#         [-0.0544]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0590],
#         [-0.0585],
#         [-0.0558],
#         [-0.0552],
#         [-0.0581],
#         [-0.0488],
#         [-0.0585],
#         [-0.0527],
#         [-0.0555],
#         [-0.0538],
#         [-0.0531],
#         [-0.0578],
#         [-0.0545],
#         [-0.0530],
#         [-0.0576],
#         [-0.0559]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0507],
#         [-0.0583],
#         [-0.0535],
#         [-0.0603],
#         [-0.0550],
#         [-0.0539],
#         [-0.0504],
#         [-0.0524],
#         [-0.0564],
#         [-0.0505],
#         [-0.0554],
#         [-0.0566],
#         [-0.0514],
#         [-0.0562],
#         [-0.0506],
#         [-0.0560]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0569],
#         [-0.0628],
#         [-0.0551],
#         [-0.0550],
#         [-0.0557],
#         [-0.0530],
#         [-0.0601],
#         [-0.0546],
#         [-0.0583],
#         [-0.0573],
#         [-0.0562],
#         [-0.0549],
#         [-0.0566],
#         [-0.0547],
#         [-0.0532],
#         [-0.0590]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0557],
#         [-0.0566],
#         [-0.0551],
#         [-0.0511],
#         [-0.0570],
#         [-0.0585],
#         [-0.0573],
#         [-0.0500],
#         [-0.0515],
#         [-0.0577],
#         [-0.0525],
#         [-0.0529],
#         [-0.0613],
#         [-0.0534],
#         [-0.0550],
#         [-0.0541]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0542],
#         [-0.0470],
#         [-0.0599],
#         [-0.0561],
#         [-0.0588],
#         [-0.0580],
#         [-0.0547],
#         [-0.0527],
#         [-0.0535],
#         [-0.0517],
#         [-0.0588],
#         [-0.0570],
#         [-0.0581],
#         [-0.0563],
#         [-0.0585],
#         [-0.0560]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0564],
#         [-0.0546],
#         [-0.0624],
#         [-0.0567],
#         [-0.0560],
#         [-0.0530],
#         [-0.0572],
#         [-0.0603],
#         [-0.0600],
#         [-0.0529],
#         [-0.0601],
#         [-0.0522],
#         [-0.0596],
#         [-0.0510],
#         [-0.0553],
#         [-0.0607]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0575],
#         [-0.0598],
#         [-0.0567],
#         [-0.0600],
#         [-0.0584],
#         [-0.0570],
#         [-0.0594],
#         [-0.0583],
#         [-0.0601],
#         [-0.0590],
#         [-0.0501],
#         [-0.0481],
#         [-0.0593],
#         [-0.0568],
#         [-0.0559],
#         [-0.0574]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0603],
#         [-0.0556],
#         [-0.0516],
#         [-0.0554],
#         [-0.0544],
#         [-0.0538],
#         [-0.0531],
#         [-0.0571],
#         [-0.0509],
#         [-0.0502],
#         [-0.0544],
#         [-0.0577],
#         [-0.0543],
#         [-0.0529],
#         [-0.0539],
#         [-0.0464]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0533],
#         [-0.0511],
#         [-0.0506],
#         [-0.0497],
#         [-0.0533],
#         [-0.0493],
#         [-0.0491],
#         [-0.0462],
#         [-0.0534],
#         [-0.0500],
#         [-0.0547],
#         [-0.0525],
#         [-0.0511],
#         [-0.0469],
#         [-0.0500],
#         [-0.0576]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 0:   3%|▎         | 10/363 [00:00<00:03, 88.53it/s, loss=nan]
# /home/chainyo/miniconda3/envs/make-me-rich/lib/python3.8/site-packages/pytorch_lightning/loops/optimization/optimizer_loop.py:145: UserWarning: `training_step` returned `None`. If this was on purpose, ignore this warning...
#   self.warning_cache.warn(
# tensor([[-0.0544],
#         [-0.0563],
#         [-0.0498],
#         [-0.0508],
#         [-0.0537],
#         [-0.0505],
#         [-0.0515],
#         [-0.0534],
#         [-0.0501],
#         [-0.0474],
#         [-0.0537],
#         [-0.0504],
#         [-0.0453],
#         [-0.0466],
#         [-0.0516],
#         [-0.0478]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0531],
#         [-0.0540],
#         [-0.0520],
#         [-0.0532],
#         [-0.0526],
#         [-0.0532],
#         [-0.0521],
#         [-0.0470],
#         [-0.0529],
#         [-0.0484],
#         [-0.0505],
#         [-0.0538],
#         [-0.0533],
#         [-0.0526],
#         [-0.0549],
#         [-0.0538]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0508],
#         [-0.0531],
#         [-0.0506],
#         [-0.0530],
#         [-0.0484],
#         [-0.0483],
#         [-0.0492],
#         [-0.0515],
#         [-0.0510],
#         [-0.0502],
#         [-0.0576],
#         [-0.0545],
#         [-0.0487],
#         [-0.0500],
#         [-0.0507],
#         [-0.0482]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0529],
#         [-0.0533],
#         [-0.0555],
#         [-0.0543],
#         [-0.0526],
#         [-0.0481],
#         [-0.0480],
#         [-0.0529],
#         [-0.0535],
#         [-0.0538],
#         [-0.0519],
#         [-0.0493],
#         [-0.0496],
#         [-0.0467],
#         [-0.0518],
#         [-0.0565]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0485],
#         [-0.0534],
#         [-0.0528],
#         [-0.0532],
#         [-0.0485],
#         [-0.0542],
#         [-0.0535],
#         [-0.0554],
#         [-0.0571],
#         [-0.0484],
#         [-0.0486],
#         [-0.0511],
#         [-0.0532],
#         [-0.0531],
#         [-0.0564],
#         [-0.0546]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0506],
#         [-0.0533],
#         [-0.0533],
#         [-0.0515],
#         [-0.0518],
#         [-0.0533],
#         [-0.0527],
#         [-0.0494],
#         [-0.0521],
#         [-0.0507],
#         [-0.0499],
#         [-0.0530],
#         [-0.0513],
#         [-0.0510],
#         [-0.0506],
#         [-0.0527]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0573],
#         [-0.0500],
#         [-0.0543],
#         [-0.0497],
#         [-0.0540],
#         [-0.0519],
#         [-0.0524],
#         [-0.0488],
#         [-0.0578],
#         [-0.0502],
#         [-0.0521],
#         [-0.0501],
#         [-0.0556],
#         [-0.0572],
#         [-0.0492],
#         [-0.0528]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0531],
#         [-0.0519],
#         [-0.0448],
#         [-0.0589],
#         [-0.0532],
#         [-0.0513],
#         [-0.0497],
#         [-0.0502],
#         [-0.0556],
#         [-0.0551],
#         [-0.0536],
#         [-0.0578],
#         [-0.0550],
#         [-0.0601],
#         [-0.0519],
#         [-0.0533]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0563],
#         [-0.0504],
#         [-0.0534],
#         [-0.0505],
#         [-0.0519],
#         [-0.0504],
#         [-0.0538],
#         [-0.0511],
#         [-0.0498],
#         [-0.0529],
#         [-0.0528],
#         [-0.0537],
#         [-0.0561],
#         [-0.0516],
#         [-0.0549],
#         [-0.0488]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0539],
#         [-0.0515],
#         [-0.0529],
#         [-0.0520],
#         [-0.0510],
#         [-0.0531],
#         [-0.0536],
#         [-0.0544],
#         [-0.0505],
#         [-0.0516],
#         [-0.0547],
#         [-0.0523],
#         [-0.0536],
#         [-0.0537],
#         [-0.0501],
#         [-0.0493]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 0:   6%|▌         | 20/363 [00:00<00:02, 134.36it/s, loss=nan]tensor([[-0.0523],
#         [-0.0574],
#         [-0.0527],
#         [-0.0548],
#         [-0.0545],
#         [-0.0534],
#         [-0.0531],
#         [-0.0553],
#         [-0.0582],
#         [-0.0538],
#         [-0.0542],
#         [-0.0505],
#         [-0.0548],
#         [-0.0484],
#         [-0.0538],
#         [-0.0497]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0594],
#         [-0.0544],
#         [-0.0551],
#         [-0.0560],
#         [-0.0525],
#         [-0.0541],
#         [-0.0563],
#         [-0.0569],
#         [-0.0531],
#         [-0.0524],
#         [-0.0527],
#         [-0.0519],
#         [-0.0544],
#         [-0.0574],
#         [-0.0530],
#         [-0.0531]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0536],
#         [-0.0506],
#         [-0.0580],
#         [-0.0516],
#         [-0.0506],
#         [-0.0565],
#         [-0.0555],
#         [-0.0548],
#         [-0.0496],
#         [-0.0502],
#         [-0.0560],
#         [-0.0520],
#         [-0.0559],
#         [-0.0558],
#         [-0.0506],
#         [-0.0569]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0542],
#         [-0.0562],
#         [-0.0578],
#         [-0.0516],
#         [-0.0541],
#         [-0.0520],
#         [-0.0529],
#         [-0.0519],
#         [-0.0528],
#         [-0.0504],
#         [-0.0547],
#         [-0.0587],
#         [-0.0536],
#         [-0.0521],
#         [-0.0519],
#         [-0.0543]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0526],
#         [-0.0556],
#         [-0.0567],
#         [-0.0552],
#         [-0.0578],
#         [-0.0513],
#         [-0.0550],
#         [-0.0549],
#         [-0.0551],
#         [-0.0565],
#         [-0.0521],
#         [-0.0540],
#         [-0.0512],
#         [-0.0584],
#         [-0.0594],
#         [-0.0565]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0516],
#         [-0.0554],
#         [-0.0512],
#         [-0.0548],
#         [-0.0542],
#         [-0.0530],
#         [-0.0536],
#         [-0.0593],
#         [-0.0581],
#         [-0.0555],
#         [-0.0562],
#         [-0.0554],
#         [-0.0569],
#         [-0.0557],
#         [-0.0521],
#         [-0.0612]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0578],
#         [-0.0561],
#         [-0.0577],
#         [-0.0556],
#         [-0.0519],
#         [-0.0520],
#         [-0.0530],
#         [-0.0550],
#         [-0.0531],
#         [-0.0496],
#         [-0.0593],
#         [-0.0539],
#         [-0.0586],
#         [-0.0503],
#         [-0.0599],
#         [-0.0580]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0561],
#         [-0.0610],
#         [-0.0516],
#         [-0.0516],
#         [-0.0547],
#         [-0.0497],
#         [-0.0548],
#         [-0.0613],
#         [-0.0577],
#         [-0.0572],
#         [-0.0505],
#         [-0.0594],
#         [-0.0558],
#         [-0.0520],
#         [-0.0553],
#         [-0.0569]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0583],
#         [-0.0529],
#         [-0.0583],
#         [-0.0561],
#         [-0.0535],
#         [-0.0547],
#         [-0.0587],
#         [-0.0548],
#         [-0.0557],
#         [-0.0525],
#         [-0.0497],
#         [-0.0509],
#         [-0.0542],
#         [-0.0589],
#         [-0.0530],
#         [-0.0532]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0549],
#         [-0.0587],
#         [-0.0546],
#         [-0.0499],
#         [-0.0551],
#         [-0.0609],
#         [-0.0608],
#         [-0.0574],
#         [-0.0526],
#         [-0.0539],
#         [-0.0586],
#         [-0.0584],
#         [-0.0538],
#         [-0.0519],
#         [-0.0550],
#         [-0.0582]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 0:   8%|▊         | 30/363 [00:00<00:02, 165.33it/s, loss=nan]tensor([[-0.0515],
#         [-0.0535],
#         [-0.0585],
#         [-0.0578],
#         [-0.0533],
#         [-0.0518],
#         [-0.0541],
#         [-0.0517],
#         [-0.0556],
#         [-0.0562],
#         [-0.0586],
#         [-0.0555],
#         [-0.0561],
#         [-0.0550],
#         [-0.0578],
#         [-0.0476]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0514],
#         [-0.0495],
#         [-0.0513],
#         [-0.0493],
#         [-0.0499],
#         [-0.0446],
#         [-0.0483],
#         [-0.0548],
#         [-0.0501],
#         [-0.0510],
#         [-0.0535],
#         [-0.0532],
#         [-0.0458],
#         [-0.0536],
#         [-0.0477],
#         [-0.0462]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.
], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0572],
#         [-0.0553],
#         [-0.0590],
#         [-0.0577],
#         [-0.0572],
#         [-0.0535],
#         [-0.0597],
#         [-0.0578],
#         [-0.0569],
#         [-0.0573],
#         [-0.0547],
#         [-0.0546],
#         [-0.0601],
#         [-0.0572],
#         [-0.0570],
#         [-0.0566]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0593],
#         [-0.0540],
#         [-0.0579],
#         [-0.0559],
#         [-0.0560],
#         [-0.0575],
#         [-0.0526],
#         [-0.0542],
#         [-0.0571]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0556]], device='cuda:0')
# tensor([[-0.0556]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0573]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0577]], device='cuda:0')
# tensor([[-0.0573]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0573]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# Epoch 0:  28%|██▊       | 100/363 [00:00<00:01, 194.46it/s, loss=nan]tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0583]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0575]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0562]], device='cuda:0')
# tensor([[-0.0575]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0589]], device='cuda:0')
# tensor([[-0.0589]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# Epoch 0:  36%|███▌      | 130/363 [00:00<00:01, 208.74it/s, loss=nan]tensor([[-0.0595]], device='cuda:0')
# tensor([[-0.0597]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0589]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0592]], device='cuda:0')
# tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0589]], device='cuda:0')
# tensor([[-0.0583]], device='cuda:0')
# tensor([[-0.0592]], device='cuda:0')
# tensor([[-0.0597]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0597]], device='cuda:0')
# tensor([[-0.0617]], device='cuda:0')
# tensor([[-0.0645]], device='cuda:0')
# tensor([[-0.0665]], device='cuda:0')
# tensor([[-0.0642]], device='cuda:0')
# tensor([[-0.0618]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0575]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0545]], device='cuda:0')
# tensor([[-0.0551]], device='cuda:0')
# tensor([[-0.0552]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0558]], device='cuda:0')
# tensor([[-0.0550]], device='cuda:0')
# tensor([[-0.0542]], device='cuda:0')
# tensor([[-0.0533]], device='cuda:0')
# tensor([[-0.0548]], device='cuda:0')
# tensor([[-0.0553]], device='cuda:0')
# tensor([[-0.0553]], device='cuda:0')
# tensor([[-0.0542]], device='cuda:0')
# tensor([[-0.0539]], device='cuda:0')
# tensor([[-0.0532]], device='cuda:0')
# tensor([[-0.0524]], device='cuda:0')
# Epoch 0:  47%|████▋     | 170/363 [00:00<00:00, 224.43it/s, loss=nan]tensor([[-0.0540]], device='cuda:0')
# tensor([[-0.0548]], device='cuda:0')
# tensor([[-0.0546]], device='cuda:0')
# tensor([[-0.0546]], device='cuda:0')
# tensor([[-0.0542]], device='cuda:0')
# tensor([[-0.0535]], device='cuda:0')
# tensor([[-0.0525]], device='cuda:0')
# tensor([[-0.0544]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0564]], device='cuda:0')
# tensor([[-0.0564]], device='cuda:0')
# tensor([[-0.0562]], device='cuda:0')
# tensor([[-0.0556]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0562]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0577]], device='cuda:0')
# tensor([[-0.0579]], device='cuda:0')
# tensor([[-0.0573]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0560]], device='cuda:0')
# tensor([[-0.0555]], device='cuda:0')
# tensor([[-0.0550]], device='cuda:0')
# tensor([[-0.0542]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0583]], device='cuda:0')
# Epoch 0:  58%|█████▊    | 210/363 [00:00<00:00, 237.03it/s, loss=nan]tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0599]], device='cuda:0')
# tensor([[-0.0599]], device='cuda:0')
# tensor([[-0.0598]], device='cuda:0')
# tensor([[-0.0592]], device='cuda:0')
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0573]], device='cuda:0')
# tensor([[-0.0569]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0579]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0589]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0603]], device='cuda:0')
# tensor([[-0.0606]], device='cuda:0')
# tensor([[-0.0603]], device='cuda:0')
# tensor([[-0.0604]], device='cuda:0')
# tensor([[-0.0601]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0609]], device='cuda:0')
# tensor([[-0.0607]], device='cuda:0')
# Epoch 0:  69%|██████▉   | 250/363 [00:01<00:00, 249.65it/s, loss=nan]tensor([[-0.0603]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0575]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0583]], device='cuda:0')
# tensor([[-0.0577]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0599]], device='cuda:0')
# tensor([[-0.0598]], device='cuda:0')
# tensor([[-0.0610]], device='cuda:0')
# tensor([[-0.0610]], device='cuda:0')
# tensor([[-0.0610]], device='cuda:0')
# tensor([[-0.0608]], device='cuda:0')
# tensor([[-0.0601]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0604]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0562]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0546]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# Epoch 0:  80%|███████▉  | 290/363 [00:01<00:00, 258.58it/s, loss=nan]tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0569]], device='cuda:0')
# tensor([[-0.0560]], device='cuda:0')
# tensor([[-0.0551]], device='cuda:0')
# tensor([[-0.0545]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0575]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0579]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0570]], device='cuda:0')
# tensor([[-0.0563]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0556]], device='cuda:0')
# tensor([[-0.0552]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0573]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# Epoch 0:  91%|█████████ | 330/363 [00:01<00:00, 267.96it/s, loss=nan]tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0577]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0566]], device='cuda:0')
# tensor([[-0.0560]], device='cuda:0')
# tensor([[-0.0569]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0562]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0579]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0583]], device='cuda:0')
# tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0598]], device='cuda:0')
# tensor([[-0.0603]], device='cuda:0')
# tensor([[-0.0607]], device='cuda:0')
# tensor([[-0.0609]], device='cuda:0')
# tensor([[-0.0601]], device='cuda:0')
# tensor([[-0.0611]], device='cuda:0')
# tensor([[-0.0611]], device='cuda:0')
# tensor([[-0.0609]], device='cuda:0')
# tensor([[-0.0604]], device='cuda:0')
# Epoch 1:   0%|          | 0/363 [00:00<?, ?it/s, loss=nan]           tensor([[-0.0533],
#         [-0.0545],
#         [-0.0581],
#         [-0.0464],
#         [-0.0531],
#         [-0.0529],
#         [-0.0536],
#         [-0.0562],
#         [-0.0566],
#         [-0.0511],
#         [-0.0539],
#         [-0.0530],
#         [-0.0581],
#         [-0.0530],
#         [-0.0545],
#         [-0.0552]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0546],
#         [-0.0505],
#         [-0.0567],
#         [-0.0550],
#         [-0.0536],
#         [-0.0559],
#         [-0.0521],
#         [-0.0526],
#         [-0.0524],
#         [-0.0573],
#         [-0.0505],
#         [-0.0536],
#         [-0.0591],
#         [-0.0549],
#         [-0.0547],
#         [-0.0524]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0511],
#         [-0.0500],
#         [-0.0513],
#         [-0.0553],
#         [-0.0565],
#         [-0.0515],
#         [-0.0490],
#         [-0.0460],
#         [-0.0595],
#         [-0.0578],
#         [-0.0541],
#         [-0.0556],
#         [-0.0539],
#         [-0.0591],
#         [-0.0510],
#         [-0.0561]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0555],
#         [-0.0589],
#         [-0.0519],
#         [-0.0513],
#         [-0.0576],
#         [-0.0544],
#         [-0.0530],
#         [-0.0561],
#         [-0.0579],
#         [-0.0555],
#         [-0.0532],
#         [-0.0519],
#         [-0.0514],
#         [-0.0541],
#         [-0.0570],
#         [-0.0510]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0540],
#         [-0.0581],
#         [-0.0550],
#         [-0.0532],
#         [-0.0550],
#         [-0.0588],
#         [-0.0505],
#         [-0.0600],
#         [-0.0581],
#         [-0.0532],
#         [-0.0603],
#         [-0.0565],
#         [-0.0560],
#         [-0.0589],
#         [-0.0527],
#         [-0.0537]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0581],
#         [-0.0539],
#         [-0.0544],
#         [-0.0559],
#         [-0.0542],
#         [-0.0601],
#         [-0.0618],
#         [-0.0564],
#         [-0.0555],
#         [-0.0574],
#         [-0.0560],
#         [-0.0569],
#         [-0.0534],
#         [-0.0535],
#         [-0.0587],
#         [-0.0530]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0530],
#         [-0.0564],
#         [-0.0605],
#         [-0.0560],
#         [-0.0585],
#         [-0.0538],
#         [-0.0551],
#         [-0.0567],
#         [-0.0603],
#         [-0.0617],
#         [-0.0576],
#         [-0.0580],
#         [-0.0581],
#         [-0.0537],
#         [-0.0563],
#         [-0.0629]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0577],
#         [-0.0558],
#         [-0.0613],
#         [-0.0611],
#         [-0.0580],
#         [-0.0517],
#         [-0.0594],
#         [-0.0637],
#         [-0.0551],
#         [-0.0597],
#         [-0.0544],
#         [-0.0577],
#         [-0.0545],
#         [-0.0554],
#         [-0.0617],
#         [-0.0626]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0573],
#         [-0.0606],
#         [-0.0560],
#         [-0.0581],
#         [-0.0505],
#         [-0.0544],
#         [-0.0519],
#         [-0.0523],
#         [-0.0523],
#         [-0.0536],
#         [-0.0525],
#         [-0.0560],
#         [-0.0557],
#         [-0.0555],
#         [-0.0523],
#         [-0.0519]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0542],
#         [-0.0527],
#         [-0.0504],
#         [-0.0544],
#         [-0.0542],
#         [-0.0547],
#         [-0.0499],
#         [-0.0499],
#         [-0.0549],
#         [-0.0571],
#         [-0.0528],
#         [-0.0495],
#         [-0.0536],
#         [-0.0450],
#         [-0.0492],
#         [-0.0505]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1:   3%|▎         | 10/363 [00:00<00:04, 71.55it/s, loss=nan]tensor([[-0.0597],
#         [-0.0496],
#         [-0.0503],
#         [-0.0511],
#         [-0.0528],
#         [-0.0425],
#         [-0.0514],
#         [-0.0545],
#         [-0.0486],
#         [-0.0538],
#         [-0.0523],
#         [-0.0476],
#         [-0.0461],
#         [-0.0575],
#         [-0.0536],
#         [-0.0515]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0517],
#         [-0.0533],
#         [-0.0499],
#         [-0.0495],
#         [-0.0532],
#         [-0.0488],
#         [-0.0566],
#         [-0.0469],
#         [-0.0551],
#         [-0.0507],
#         [-0.0490],
#         [-0.0509],
#         [-0.0524],
#         [-0.0523],
#         [-0.0557],
#         [-0.0472]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0549],
#         [-0.0510],
#         [-0.0508],
#         [-0.0473],
#         [-0.0536],
#         [-0.0506],
#         [-0.0529],
#         [-0.0464],
#         [-0.0462],
#         [-0.0476],
#         [-0.0511],
#         [-0.0511],
#         [-0.0515],
#         [-0.0484],
#         [-0.0473],
#         [-0.0555]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0524],
#         [-0.0501],
#         [-0.0540],
#         [-0.0525],
#         [-0.0532],
#         [-0.0516],
#         [-0.0517],
#         [-0.0495],
#         [-0.0526],
#         [-0.0538],
#         [-0.0488],
#         [-0.0531],
#         [-0.0514],
#         [-0.0528],
#         [-0.0518],
#         [-0.0502]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0493],
#         [-0.0540],
#         [-0.0543],
#         [-0.0520],
#         [-0.0499],
#         [-0.0494],
#         [-0.0537],
#         [-0.0527],
#         [-0.0535],
#         [-0.0587],
#         [-0.0532],
#         [-0.0482],
#         [-0.0501],
#         [-0.0564],
#         [-0.0571],
#         [-0.0466]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0499],
#         [-0.0585],
#         [-0.0500],
#         [-0.0538],
#         [-0.0498],
#         [-0.0511],
#         [-0.0537],
#         [-0.0576],
#         [-0.0537],
#         [-0.0421],
#         [-0.0531],
#         [-0.0532],
#         [-0.0488],
#         [-0.0554],
#         [-0.0520],
#         [-0.0607]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0518],
#         [-0.0573],
#         [-0.0481],
#         [-0.0507],
#         [-0.0520],
#         [-0.0540],
#         [-0.0508],
#         [-0.0500],
#         [-0.0540],
#         [-0.0547],
#         [-0.0524],
#         [-0.0529],
#         [-0.0480],
#         [-0.0498],
#         [-0.0479],
#         [-0.0559]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0528],
#         [-0.0529],
#         [-0.0508],
#         [-0.0534],
#         [-0.0524],
#         [-0.0500],
#         [-0.0488],
#         [-0.0524],
#         [-0.0508],
#         [-0.0580],
#         [-0.0543],
#         [-0.0528],
#         [-0.0528],
#         [-0.0523],
#         [-0.0561],
#         [-0.0518]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0527],
#         [-0.0499],
#         [-0.0530],
#         [-0.0518],
#         [-0.0484],
#         [-0.0537],
#         [-0.0573],
#         [-0.0494],
#         [-0.0547],
#         [-0.0524],
#         [-0.0502],
#         [-0.0574],
#         [-0.0546],
#         [-0.0553],
#         [-0.0566],
#         [-0.0508]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0525],
#         [-0.0479],
#         [-0.0527],
#         [-0.0507],
#         [-0.0548],
#         [-0.0499],
#         [-0.0493],
#         [-0.0522],
#         [-0.0472],
#         [-0.0593],
#         [-0.0552],
#         [-0.0543],
#         [-0.0470],
#         [-0.0542],
#         [-0.0544],
#         [-0.0536]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1:   6%|▌         | 20/363 [00:00<00:03, 111.50it/s, loss=nan]tensor([[-0.0504],
#         [-0.0552],
#         [-0.0548],
#         [-0.0560],
#         [-0.0551],
#         [-0.0527],
#         [-0.0494],
#         [-0.0549],
#         [-0.0577],
#         [-0.0570],
#         [-0.0537],
#         [-0.0536],
#         [-0.0555],
#         [-0.0504],
#         [-0.0574],
#         [-0.0572]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0566],
#         [-0.0518],
#         [-0.0496],
#         [-0.0555],
#         [-0.0507],
#         [-0.0574],
#         [-0.0526],
#         [-0.0609],
#         [-0.0580],
#         [-0.0485],
#         [-0.0562],
#         [-0.0546],
#         [-0.0483],
#         [-0.0511],
#         [-0.0504],
#         [-0.0524]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0576],
#         [-0.0529],
#         [-0.0519],
#         [-0.0525],
#         [-0.0475],
#         [-0.0542],
#         [-0.0560],
#         [-0.0479],
#         [-0.0570],
#         [-0.0529],
#         [-0.0525],
#         [-0.0528],
#         [-0.0534],
#         [-0.0491],
#         [-0.0525],
#         [-0.0563]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0529],
#         [-0.0514],
#         [-0.0525],
#         [-0.0518],
#         [-0.0550],
#         [-0.0542],
#         [-0.0510],
#         [-0.0490],
#         [-0.0585],
#         [-0.0547],
#         [-0.0538],
#         [-0.0571],
#         [-0.0563],
#         [-0.0551],
#         [-0.0546],
#         [-0.0560]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0589],
#         [-0.0575],
#         [-0.0544],
#         [-0.0519],
#         [-0.0569],
#         [-0.0564],
#         [-0.0491],
#         [-0.0525],
#         [-0.0586],
#         [-0.0586],
#         [-0.0506],
#         [-0.0516],
#         [-0.0547],
#         [-0.0576],
#         [-0.0527],
#         [-0.0574]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0509],
#         [-0.0514],
#         [-0.0553],
#         [-0.0537],
#         [-0.0566],
#         [-0.0524],
#         [-0.0563],
#         [-0.0517],
#         [-0.0576],
#         [-0.0548],
#         [-0.0554],
#         [-0.0562],
#         [-0.0534],
#         [-0.0506],
#         [-0.0514],
#         [-0.0573]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.0589],
#         [-0.0555],
#         [-0.0568],
#         [-0.0562],
#         [-0.0573],
#         [-0.0577],
#         [-0.0514],
#         [-0.0587],
#         [-0.0502],
#         [-0.0547],
#         [-0.0593],
#         [-0.0573],
#         [-0.0530],
#         [-0.0497],
#         [-0.0570],
# ...
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0595]], device='cuda:0')
# tensor([[-0.0597]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0589]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0592]], device='cuda:0')
# tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0589]], device='cuda:0')
# tensor([[-0.0583]], device='cuda:0')
# tensor([[-0.0592]], device='cuda:0')
# tensor([[-0.0597]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0597]], device='cuda:0')
# tensor([[-0.0617]], device='cuda:0')
# tensor([[-0.0645]], device='cuda:0')
# tensor([[-0.0665]], device='cuda:0')
# tensor([[-0.0642]], device='cuda:0')
# tensor([[-0.0618]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0575]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0545]], device='cuda:0')
# tensor([[-0.0551]], device='cuda:0')
# tensor([[-0.0552]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0558]], device='cuda:0')
# tensor([[-0.0550]], device='cuda:0')
# tensor([[-0.0542]], device='cuda:0')
# tensor([[-0.0533]], device='cuda:0')
# tensor([[-0.0548]], device='cuda:0')
# tensor([[-0.0553]], device='cuda:0')
# tensor([[-0.0553]], device='cuda:0')
# tensor([[-0.0542]], device='cuda:0')
# tensor([[-0.0539]], device='cuda:0')
# tensor([[-0.0532]], device='cuda:0')
# tensor([[-0.0524]], device='cuda:0')
# tensor([[-0.0540]], device='cuda:0')
# tensor([[-0.0548]], device='cuda:0')
# tensor([[-0.0546]], device='cuda:0')
# tensor([[-0.0546]], device='cuda:0')
# tensor([[-0.0542]], device='cuda:0')
# tensor([[-0.0535]], device='cuda:0')
# tensor([[-0.0525]], device='cuda:0')
# tensor([[-0.0544]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# Epoch 2:  50%|████▉     | 180/363 [00:00<00:00, 226.72it/s, loss=nan]tensor([[-0.0564]], device='cuda:0')
# tensor([[-0.0564]], device='cuda:0')
# tensor([[-0.0562]], device='cuda:0')
# tensor([[-0.0556]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0562]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0577]], device='cuda:0')
# tensor([[-0.0579]], device='cuda:0')
# tensor([[-0.0573]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0560]], device='cuda:0')
# tensor([[-0.0555]], device='cuda:0')
# tensor([[-0.0550]], device='cuda:0')
# tensor([[-0.0542]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0583]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0599]], device='cuda:0')
# tensor([[-0.0599]], device='cuda:0')
# tensor([[-0.0598]], device='cuda:0')
# tensor([[-0.0592]], device='cuda:0')
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0573]], device='cuda:0')
# tensor([[-0.0569]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0579]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0589]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# Epoch 2:  66%|██████▌   | 240/363 [00:00<00:00, 244.43it/s, loss=nan]tensor([[-0.0603]], device='cuda:0')
# tensor([[-0.0606]], device='cuda:0')
# tensor([[-0.0603]], device='cuda:0')
# tensor([[-0.0604]], device='cuda:0')
# tensor([[-0.0601]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0609]], device='cuda:0')
# tensor([[-0.0607]], device='cuda:0')
# tensor([[-0.0603]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0575]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0583]], device='cuda:0')
# tensor([[-0.0577]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0599]], device='cuda:0')
# tensor([[-0.0598]], device='cuda:0')
# tensor([[-0.0610]], device='cuda:0')
# tensor([[-0.0610]], device='cuda:0')
# tensor([[-0.0610]], device='cuda:0')
# tensor([[-0.0608]], device='cuda:0')
# tensor([[-0.0601]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0604]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0562]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0546]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0569]], device='cuda:0')
# tensor([[-0.0560]], device='cuda:0')
# tensor([[-0.0551]], device='cuda:0')
# tensor([[-0.0545]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# Epoch 2:  83%|████████▎ | 300/363 [00:01<00:00, 246.70it/s, loss=nan]tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0575]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0579]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0570]], device='cuda:0')
# tensor([[-0.0563]], device='cuda:0')
# tensor([[-0.0557]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0568]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0556]], device='cuda:0')
# tensor([[-0.0552]], device='cuda:0')
# tensor([[-0.0565]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0573]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0584]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0577]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0578]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0580]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0566]], device='cuda:0')
# tensor([[-0.0560]], device='cuda:0')
# tensor([[-0.0569]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0574]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0562]], device='cuda:0')
# tensor([[-0.0576]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0582]], device='cuda:0')
# tensor([[-0.0579]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0571]], device='cuda:0')
# tensor([[-0.0583]], device='cuda:0')
# Epoch 2:  99%|█████████▉| 360/363 [00:01<00:00, 252.28it/s, loss=nan]tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0598]], device='cuda:0')
# tensor([[-0.0603]], device='cuda:0')
# tensor([[-0.0607]], device='cuda:0')
# tensor([[-0.0609]], device='cuda:0')
# tensor([[-0.0601]], device='cuda:0')
# tensor([[-0.0611]], device='cuda:0')
# tensor([[-0.0611]], device='cuda:0')
# tensor([[-0.0609]], device='cuda:0')
# tensor([[-0.0604]], device='cuda:0')
# Epoch 2: 100%|██████████| 363/363 [00:01<00:00, 239.22it/s, loss=nan]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]tensor([[-0.0596]], device='cuda:0')
# tensor([[-0.0589]], device='cuda:0')
# tensor([[-0.0596]], device='cuda:0')
# tensor([[-0.0596]], device='cuda:0')
# tensor([[-0.0598]], device='cuda:0')
# tensor([[-0.0592]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0586]], device='cuda:0')
# tensor([[-0.0579]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# Testing:   6%|▋         | 10/155 [00:00<00:01, 89.71it/s]tensor([[-0.0590]], device='cuda:0')
# tensor([[-0.0601]], device='cuda:0')
# tensor([[-0.0610]], device='cuda:0')
# tensor([[-0.0616]], device='cuda:0')
# tensor([[-0.0617]], device='cuda:0')
# tensor([[-0.0620]], device='cuda:0')
# tensor([[-0.0629]], device='cuda:0')
# tensor([[-0.0619]], device='cuda:0')
# tensor([[-0.0614]], device='cuda:0')
# tensor([[-0.0613]], device='cuda:0')
# tensor([[-0.0608]], device='cuda:0')
# tensor([[-0.0605]], device='cuda:0')
# tensor([[-0.0602]], device='cuda:0')
# tensor([[-0.0605]], device='cuda:0')
# tensor([[-0.0613]], device='cuda:0')
# tensor([[-0.0615]], device='cuda:0')
# tensor([[-0.0612]], device='cuda:0')
# tensor([[-0.0607]], device='cuda:0')
# tensor([[-0.0603]], device='cuda:0')
# tensor([[-0.0595]], device='cuda:0')
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0592]], device='cuda:0')
# tensor([[-0.0598]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0593]], device='cuda:0')
# tensor([[-0.0587]], device='cuda:0')
# tensor([[-0.0581]], device='cuda:0')
# tensor([[-0.0588]], device='cuda:0')
# tensor([[-0.0591]], device='cuda:0')
# tensor([[-0.0592]], device='cuda:0')
# tensor([[-0.0594]], device='cuda:0')
# tensor([[-0.0608]], device='cuda:0')
# tensor([[-0.0612]], device='cuda:0')
# tensor([[-0.0615]], device='cuda:0')
# tensor([[-0.0625]], device='cuda:0')
# tensor([[-0.0636]], device='cuda:0')
# tensor([[-0.0647]], device='cuda:0')
# tensor([[-0.0643]], device='cuda:0')
# tensor([[-0.0637]], device='cuda:0')
# tensor([[-0.0634]], device='cuda:0')
# Testing:  32%|███▏      | 50/155 [00:00<00:00, 249.38it/s]tensor([[-0.0628]], device='cuda:0')
# tensor([[-0.0637]], device='cuda:0')
# tensor([[-0.0635]], device='cuda:0')
# tensor([[-0.0635]], device='cuda:0')
# tensor([[-0.0633]], device='cuda:0')
# tensor([[-0.0638]], device='cuda:0')
# tensor([[-0.0632]], device='cuda:0')
# tensor([[-0.0626]], device='cuda:0')
# tensor([[-0.0629]], device='cuda:0')
# tensor([[-0.0635]], device='cuda:0')
# tensor([[-0.0637]], device='cuda:0')
# tensor([[-0.0626]], device='cuda:0')
# tensor([[-0.0617]], device='cuda:0')
# tensor([[-0.0614]], device='cuda:0')
# tensor([[-0.0608]], device='cuda:0')
# tensor([[-0.0618]], device='cuda:0')
# tensor([[-0.0616]], device='cuda:0')
# tensor([[-0.0612]], device='cuda:0')
# tensor([[-0.0614]], device='cuda:0')
# tensor([[-0.0615]], device='cuda:0')
# tensor([[-0.0610]], device='cuda:0')
# tensor([[-0.0602]], device='cuda:0')
# tensor([[-0.0617]], device='cuda:0')
# tensor([[-0.0637]], device='cuda:0')
# tensor([[-0.0647]], device='cuda:0')
# tensor([[-0.0649]], device='cuda:0')
# tensor([[-0.0650]], device='cuda:0')
# tensor([[-0.0652]], device='cuda:0')
# tensor([[-0.0654]], device='cuda:0')
# tensor([[-0.0666]], device='cuda:0')
# tensor([[-0.0665]], device='cuda:0')
# tensor([[-0.0656]], device='cuda:0')
# tensor([[-0.0653]], device='cuda:0')
# tensor([[-0.0648]], device='cuda:0')
# tensor([[-0.0644]], device='cuda:0')
# tensor([[-0.0642]], device='cuda:0')
# tensor([[-0.0639]], device='cuda:0')
# tensor([[-0.0632]], device='cuda:0')
# tensor([[-0.0633]], device='cuda:0')
# tensor([[-0.0625]], device='cuda:0')
# Testing:  58%|█████▊    | 90/155 [00:00<00:00, 295.55it/s]tensor([[-0.0625]], device='cuda:0')
# tensor([[-0.0626]], device='cuda:0')
# tensor([[-0.0619]], device='cuda:0')
# tensor([[-0.0618]], device='cuda:0')
# tensor([[-0.0624]], device='cuda:0')
# tensor([[-0.0624]], device='cuda:0')
# tensor([[-0.0625]], device='cuda:0')
# tensor([[-0.0611]], device='cuda:0')
# tensor([[-0.0608]], device='cuda:0')
# tensor([[-0.0607]], device='cuda:0')
# tensor([[-0.0615]], device='cuda:0')
# tensor([[-0.0617]], device='cuda:0')
# tensor([[-0.0627]], device='cuda:0')
# tensor([[-0.0636]], device='cuda:0')
# tensor([[-0.0636]], device='cuda:0')
# tensor([[-0.0627]], device='cuda:0')
# tensor([[-0.0628]], device='cuda:0')
# tensor([[-0.0637]], device='cuda:0')
# tensor([[-0.0643]], device='cuda:0')
# tensor([[-0.0644]], device='cuda:0')
# tensor([[-0.0635]], device='cuda:0')
# tensor([[-0.0631]], device='cuda:0')
# tensor([[-0.0634]], device='cuda:0')
# tensor([[-0.0632]], device='cuda:0')
# tensor([[-0.0627]], device='cuda:0')
# tensor([[-0.0631]], device='cuda:0')
# tensor([[-0.0633]], device='cuda:0')
# tensor([[-0.0628]], device='cuda:0')
# tensor([[-0.0622]], device='cuda:0')
# tensor([[-0.0619]], device='cuda:0')
# tensor([[-0.0614]], device='cuda:0')
# tensor([[-0.0619]], device='cuda:0')
# tensor([[-0.0626]], device='cuda:0')
# tensor([[-0.0625]], device='cuda:0')
# tensor([[-0.0627]], device='cuda:0')
# tensor([[-0.0623]], device='cuda:0')
# tensor([[-0.0617]], device='cuda:0')
# tensor([[-0.0611]], device='cuda:0')
# tensor([[-0.0616]], device='cuda:0')
# tensor([[-0.0613]], device='cuda:0')
# Testing:  84%|████████▍ | 130/155 [00:00<00:00, 313.64it/s]tensor([[-0.0611]], device='cuda:0')
# tensor([[-0.0611]], device='cuda:0')
# tensor([[-0.0607]], device='cuda:0')
# tensor([[-0.0628]], device='cuda:0')
# tensor([[-0.0653]], device='cuda:0')
# tensor([[-0.0641]], device='cuda:0')
# tensor([[-0.0621]], device='cuda:0')
# tensor([[-0.0600]], device='cuda:0')
# tensor([[-0.0585]], device='cuda:0')
# tensor([[-0.0572]], device='cuda:0')
# tensor([[-0.0560]], device='cuda:0')
# tensor([[-0.0550]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0567]], device='cuda:0')
# tensor([[-0.0569]], device='cuda:0')
# tensor([[-0.0564]], device='cuda:0')
# tensor([[-0.0560]], device='cuda:0')
# tensor([[-0.0553]], device='cuda:0')
# tensor([[-0.0546]], device='cuda:0')
# tensor([[-0.0556]], device='cuda:0')
# tensor([[-0.0561]], device='cuda:0')
# tensor([[-0.0560]], device='cuda:0')
# tensor([[-0.0555]], device='cuda:0')
# tensor([[-0.0544]], device='cuda:0')
# tensor([[-0.0535]], device='cuda:0')
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_loss': 0.4990306794643402, 'test_loss_epoch': 0.4990306794643402}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████| 155/155 [00:00<00:00, 274.70it/s]
